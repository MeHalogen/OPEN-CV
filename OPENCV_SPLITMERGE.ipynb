# %% [markdown]
# <a href="https://colab.research.google.com/github/MeHalogen/OPEN-CV/blob/main/OPENCV_SPLITMERGE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive",)
# Out:
# Mounted at /content/drive

# %%
import os
import sys
os.chdir('/content/drive/My Drive/Colab Notebooks/IV_CSE341')
# !pwd
ROOT_DIR = os.path.abspath("")
print (ROOT_DIR)
sys.path.append(ROOT_DIR)
# Out:
# /content/drive/My Drive/Colab Notebooks/IV_CSE341
# /content/drive/My Drive/Colab Notebooks/IV_CSE341

# %%
def plt_imshow(title, image):
  # convert the image frame BGR to RGB color space and display it
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  plt.imshow(image)
  plt.title(title)
  plt.grid(False)
  plt.show()

# %%
# import the necessary packages
from matplotlib import pyplot as plt
import argparse
import cv2
import numpy as np

# %%
args = {
	"image": "opencv.jpg",
}

# %%
image=cv2.imread(args["image"])
plt_imshow("Original", image)
(B, G, R) = cv2.split(image)
plt_imshow("Red", R)
plt_imshow("Blue", B)
plt_imshow("Green", G)

# %%
merged = cv2.merge([B, G, R])
plt_imshow("Merged", merged)

# %%
zeros = np.zeros(image.shape[:2], dtype="uint8")
plt_imshow("Red", cv2.merge([zeros, zeros, R]))
plt_imshow("Blue", cv2.merge([B, zeros, zeros]))
plt_imshow("Green", cv2.merge([zeros, G, zeros]))
