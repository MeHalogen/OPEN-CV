# %% [markdown]
# <a href="https://colab.research.google.com/github/MeHalogen/OPEN-CV/blob/main/OPENCV_IMAGE_ARITHMETIC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive",)
# Out:
# Mounted at /content/drive

# %%
import os
import sys
os.chdir('/content/drive/My Drive/Colab Notebooks/IV_CSE341')
# !pwd
ROOT_DIR = os.path.abspath("")
print (ROOT_DIR)
sys.path.append(ROOT_DIR)
# Out:
# /content/drive/My Drive/Colab Notebooks/IV_CSE341
# /content/drive/My Drive/Colab Notebooks/IV_CSE341

# %%
# import the necessary packages
from matplotlib import pyplot as plt
import argparse
import cv2
import numpy as np

# %%
def plt_imshow(title, image):
  # convert the image frame BGR to RGB color space and display it
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  plt.imshow(image)
  plt.title(title)
  plt.grid(False)
  plt.show()

# %%
args = {
	"image": "download.jpg",
}

# %%
image=cv2.imread(args["image"])
M=np.ones(image.shape, dtype="uint8") + 99
plt_imshow("Original", image)

# %%
add = cv2.add(image,M)
sub = cv2.subtract(image,M)
plt.figure()
plt_imshow("added", add)
plt.figure()
plt_imshow("subtracted", sub)
