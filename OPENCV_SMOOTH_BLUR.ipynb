# %% [markdown]
# <a href="https://colab.research.google.com/github/MeHalogen/OPEN-CV/blob/main/OPENCV_SMOOTH_BLUR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive",)
# Out:
# Mounted at /content/drive

# %%
import os
import sys
os.chdir('/content/drive/My Drive/Colab Notebooks/IV_CSE341')
# !pwd
ROOT_DIR = os.path.abspath("")
print (ROOT_DIR)
sys.path.append(ROOT_DIR)
# Out:
# /content/drive/My Drive/Colab Notebooks/IV_CSE341
# /content/drive/My Drive/Colab Notebooks/IV_CSE341

# %%
def plt_imshow(title, image):
  # convert the image frame BGR to RGB color space and display it
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  plt.imshow(image)
  plt.title(title)
  plt.grid(False)
  plt.show()

# %%
# import the necessary packages
from matplotlib import pyplot as plt
import argparse
import cv2
import numpy as np

# %%
args = {
	"image": "scenery.jpg",
}

# %%
image=cv2.imread(args["image"])
plt_imshow("Original", image)

# %%
blur = cv2.blur(image,(5,5))

plt.subplot(121),plt.imshow(image),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
dst = cv2.GaussianBlur(image,(7,5),cv2.BORDER_DEFAULT)
plt_imshow("Gaussian blur", dst)

# %%
median = cv2.medianBlur(image,5)
plt_imshow("Median Filtering", median)

# %%
params = [{11, 7, 21}, {11, 41, 21}, {11, 61, 39}]

for (diameter, sigmaColor, sigmaSpace) in params:
  blurred = cv2.bilateralFilter(image, diameter, sigmaColor, sigmaSpace)

  title = "Blurred d={}, sc={}, ss={}".format(diameter, sigmaColor, sigmaSpace)

  plt_imshow(title, blurred)
